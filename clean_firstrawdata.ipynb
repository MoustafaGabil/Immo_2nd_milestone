# %%
Data_set = pd.read_csv("all_provinces_data.csv")
Data_set.Locality.value_counts()
# Out:
# Locality
# Antwerpen       439
# Uccle           398
# Bruxelles       346
# Ixelles         344
# ANTWERPEN       274
#                ...
# MALDEREN          1
# GOETSENHOVEN      1
# LOT               1
# DILBEEK           1
# Linkebeek         1
# Name: count, Length: 1376, dtype: int64

# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt

 # importing dataset

# Load the file to the data_set
data_set= pd.read_csv('filtered_data_residential.csv')

# Remove commas and periods from the specified column
data_set['Street'] = data_set['Street'].str.replace('[,\.]', '', regex=True)

# Remove white spaces  (leading, trailing, or extra spaces between words)
data_set = data_set.apply(lambda x: x.str.strip().str.replace('\s+', ' ', regex=True) if x.dtype == "object" else x)
# fill None when the value is empty
data_set = data_set.fillna('None')

# Create a new CSV file with cleaned data
data_set.to_csv('test.csv')

# %%
data_set.head()
# Out:
#    Property ID    Region  Province  District             Locality  PostalCode  \
# 0     20233236  Brussels  Brussels  Brussels            Bruxelles        1000
# 1     20226422  Brussels  Brussels  Brussels  Woluwe-Saint-Pierre        1150
# 2     11445541  Brussels  Brussels  Brussels            Bruxelles        1020
# 3     20093183  Brussels  Brussels  Brussels               Forest        1190
# 4     20240551  Flanders   Antwerp   Antwerp              Wilrijk        2610
#
#                                  Street    Price  \
# 0                    Rue Saint-Ghislain   225000
# 1              Avenue Edmond Parmentier  1375000
# 2  Avenue De La Bugrane - Stalkruidlaan  1000000
# 3  Place Saint-Denis - Sint-Denijsplein   565000
# 4                       Vaderlandstraat   410000
#
#                           PriceType PropertyType  ... Garden_Area FacadeCount  \
# 0  first_session_with_reserve_price        HOUSE  ...        None        None
# ...
