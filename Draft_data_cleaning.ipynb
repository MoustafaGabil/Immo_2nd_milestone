# %%
import numpy as np
import pandas as pd
df = pd.read_csv('C:\\Users\\mgabi\\Desktop\\becode\\becode_projects\\Immo_2nd_milestone\\merged_data_15_oct.csv')

# %%
df.head()
# Out:
#    Property ID    Region  Province  District               Locality  \
# 0     20233512  Brussels  Brussels  Brussels  Saint-Josse-ten-Noode
# 1     20233236  Brussels  Brussels  Brussels              Bruxelles
# 2     20226422  Brussels  Brussels  Brussels    Woluwe-Saint-Pierre
# 3     11445541  Brussels  Brussels  Brussels              Bruxelles
# 4     20093183  Brussels  Brussels  Brussels                 Forest
#
#    PostalCode                                Street      Price  \
# 0        1210                    Boulevard d'Anvers        NaN
# 1        1000                    Rue Saint-Ghislain   225000.0
# 2        1150              Avenue Edmond Parmentier  1375000.0
# 3        1020  Avenue De La Bugrane - Stalkruidlaan  1000000.0
# 4        1190  Place Saint-Denis - Sint-Denijsplein   565000.0
#
#                           PriceType     PropertyType  ... Garden_Area  \
# 0                        group_sale  APARTMENT_GROUP  ...         NaN
# ...

# %%
df['KitchenType'] = df['KitchenType'].apply(lambda x: 1 if pd.notnull(x) else 0) #lambda x: ... is an anonymous function (a function without a name) that takes each value x from the "KitchenType" column and performs an operation on it.

# %%
data_count = df['Property ID'].count()
Furnished_count = df['Furnished'].sum()
swimming_pool_count = df['SwimmingPool'].sum()
Open_fire_count = df['Open_fire'].sum()
Terrace_Area_count = df['Terrace_Area'].count()
# Out:
# np.int64(2651)

# %%
print(data_count) 
print(Furnished_count) 
print(swimming_pool_count) 
print(Open_fire_count) 
print(Terrace_Area_count)
# Out:
# 6000
# 186
# 96
# 293
# 2651
